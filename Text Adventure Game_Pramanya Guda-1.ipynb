# %% [markdown]
# Welcome to the text adventure game of Sherlock Holmes: Pursuit of the Python.
# This game immerses players in the intriguing world of mystery-solving and the science of deduction. The player is the niece/nephew of Dr. John Watson; Sherlock's partner in crime. The narrative as always unfolds from the infamous 221B Baker Street, where Sherlock Holmes involves his eager relative in a new case- A murder, stolen artifact, and the python. The first stage starts with finding the dead body and investigating about the stolen artifact and examining the museum. Sherlock and the player goes on hunting for clues, making deduction and moving forward with the game. In the second stage, they find out about the secret society through the secret workroom in the victim's house. The later stages involve action based confrontation and revealing the connections between the victim, the artifact and the python.
#
# Game based-on: Sherlock Holmes
# Source: Sherlock. (2023). BBC. https://www.bbc.co.uk/programmes/b018ttws
#
# ‌

# %%
def player_name(): #enter your name to begin
    name = input("Enter your name: ")
    return name

def introduction(): #introduction to the game of sherlock holmes
    print("\U0001F50E Welcome to another epicsode of the 'Sherlock Holmes: Pursuit of the Python'")
    print("""As you set your foot into the dimly lit entrance room of the infamous 221B Baker Street, 
    the haunting melody of Sherlock's violin is heard. 
    Dr. John Watson, your dearest uncle, is away on a honeymoon with Mary, 
    leaving you to the high-functioning sociopath. You shriver entering the sitting hall and awkwardly break the silence;
    'Hey Sherlock, it's me, your niece/nephew. I was bored, I came to visit, let's play murder! I heard uncle talk about all the interesting mysteries. 
    Is there anything I can help you with? Perhaps any new case?''""")
    print("Sherlock puts down his violin, and says, 'I knew you'd be my favorite, I taught you well. Let's set my dear , the game is afoot!'")

def epicsode_1(): #take up the case and investigate
    print("\nEpicsode 1: The Symbol of the Python")
    print("""A valuable artifact has disappeared from the British Museum, 
    and the lifeless body of the museum's keymaster and researcher, Mr. Penelope Maxwell, was discovered, 
    accompanied by a enigmatic symbol left behind at the crime scene.""")
    print("Holmes believe from the symbol that it's the work of the notorious criminal known as 'The Python'.")
    print("")
    print("1. Examine the crime scene.")
    print("2. Go to the victim's house.")
    choice = input("Make a deduction (1 or 2): ")
    print("")

    if choice == "1":
        print("Ah, can you be any quicker with that? What is it like in your head? ")
        epicsode_2()
    elif choice == "2":
        epicsode_2()
            
def epicsode_2(): #gather evidences and showoff your skills 
    print("\nEpicsode 2: The search of the Python")
    print("Upon arriving at Fairmount Avenue, Lady Maxwell gives a narrative of the situation.")
    print("")
    print("1. Examine the workroom for any hidden secrets.")
    print("2. Talk to the staff members about any unusual occurrences.")
    print("3. Locate a secret hideout in his library.")
    choice = input("Make a deduction (1, 2, or 3): ")
    print("")

    if choice == "1":
        print("You are thinking, it's annoying! Move on to the next part.")
        epicsode_3()
    elif choice == "2":
        print("You find out about the packages sent every Thursday.")
        epicsode_3()
    elif choice == "3":
        print("""You gather information about the mysterious Python threat, Percival Faxville, 
              his research, and a threatening letter.""")
        epicsode_3()
        
def epicsode_3():
    print("\nEpisode 3: Places the pieces")
    print("""As you dig deeper with Mr. Holmes, you unravel that there is a connection between the disappeared artifact, 
          the murder of the Mr. Maxwell, and the secret society.""")
    print("")
    print("1. Investigate the secret society's underground meeting.")
    print("2. Analyze the packages sent and the threatening Python letter.")
    print("3. Get yourself an arrest warrant to discreetly talk to an uncover jailer for information about the python.")
    choice = input("Make a deduction (1, 2 or 3): ")
    print("")

    if choice == "1":
        print("You sneak into the secret society's meeting place and overhear a conversation about their next move.")
        print("After sneaking into the secret society building, you come across guards, its time to act before you think.")
        print("A. Fight the guards slowly without making any noise.")
        print("B. Run away making noise in Sherlock style to stop the meeting's transcation to happen.")
        print("C. Or do you have any other idea on mind?")
        print("")
        choice = input("Make a choice (A, B or C): ")
        
        if choice == "A":
            print("You have to stay hidden to know what the meeting about and gather information to attack at the right time.")
            epicsode_4()
        elif choice == "B":
            print("That was chaos but a good show, you managed to stop the transcations and confront the members of the society.")
            epicsode_4()
        else:
            print("Nope, not a valid choice, give a better shot.")
            
    elif choice == "2":
        print("You carefully analyze the threatening letter and find a hidden message that leads you to the Python's den.")
        epicsode_4()
    elif choice == "3":
        print("Bad, bad choice, wrong! Only Mycroft can get us out now.")
        
def epicsode_4():
    print("\nEpisode 4: End the Python's Pursuit")
    print("You have successfully tracked down the Python's den. It's time to end the game in the Sherlock style.")
    print("")
    print("1. Confront the Python.")
    print("2. Gather more information before concluding.")
    choice = input("Make a deduction (1 or 2): ")
    print("")

    if choice == "1":
        win()
    elif choice == "2":
        fail()

def win():
    print("Marvelous! You've solved the case!")

def fail():
    print("You're lower the IQ than the entire street. Game over!")

def main():
    player_name()
    introduction()

    while True:
        epicsode_1()
        play_again = input("Do you want to play again? (yes/no): ").lower()
        if play_again != "yes":
            print("See you again with a new case. Goodbye!")
            break

if __name__ == "__main__":
    main()
# Out:
# Enter your name: Maya
# 🔎 Welcome to another epicsode of the 'Sherlock Holmes: Pursuit of the Python'
# As you set your foot into the dimly lit entrance room of the infamous 221B Baker Street,
#     the haunting melody of Sherlock's violin is heard.
#     Dr. John Watson, your dearest uncle, is away on a honeymoon with Mary,
#     leaving you to the high-functioning sociopath. You shriver entering the sitting hall and awkwardly break the silence;
#     'Hey Sherlock, it's me, your niece/nephew. I was bored, I came to visit, let's play murder! I heard uncle talk about all the interesting mysteries.
#     Is there anything I can help you with? Perhaps any new case?''
# Sherlock puts down his violin, and says, 'I knew you'd be my favorite, I taught you well. Let's set my dear , the game is afoot!'
#
# Epicsode 1: The Symbol of the Python
# A valuable artifact has disappeared from the British Museum,
# ...

# %% [markdown]
# Bibilography:
#
# ChatGPT - 1. Asked few framing words for the game story
#
#
#            Certainly! Let's create a condensed version of the text adventure for each example:
#
# **Example 1: The Mysterious Disappearance**
#
# *You're in 221B Baker Street. A valuable artifact vanished from the British Museum. Holmes suspects "The Python." What will you do?*
#
# 1. **Investigate the Crime Scene**
# 2. **Examine the Symbol**
# 3. **Interview Witnesses**
#
# **Example 2: The Cryptic Cipher**
#
# *Holmes finds a cipher leading to the Python's hideout. Navigate dark alleys, decipher the message, and confront the Python.*
#
# 1. **Decipher the Cipher**
# 2. **Navigate the Dark Alleys**
# 3. **Confront the Python**
#
# **Example 3: The Grand Reveal**
#
# *Cornered in the Python's lair, Holmes unravels the criminal's identity. Choose how to conclude the case.*
#
# 1. **Convince the Python to Surrender**
# 2. **Engage in a Chess Match**
# 3. **Summon Scotland Yard**
#
# Make choices wisely, and see if you can outsmart the Python and aid Sherlock Holmes in solving the mysterious case!
#
#           Used: None
#
# 2. unicode number for emojis used
#
#           Response:
#           The Unicode character for the detective emoji or Sherlock Holmes emoji is represented by 🕵️. The code point for this emoji is U+1F575.
#
# Here's an example of how you can use it in Python:
#
# ```python
# print("Sherlock Holmes: \U0001F575")  # This will print "Sherlock Holmes: 🕵️"
# ```
#
# Feel free to use this Unicode character in your Python code wherever you'd like to represent Sherlock Holmes.
#
#           Used:
#           magnifing glass unicode character
